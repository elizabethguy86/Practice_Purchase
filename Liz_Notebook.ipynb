# %%
import pandas as pd
import numpy as np
import datetime as dt

# %%
train_df = pd.read_csv('train.csv')

# %%
train_df.head()
# Out:
#   Title           Address.1st.Line Address.2nd.Line             City State  \
# 0   DMD      6335 E. Mountain View              NaN  Paradise Valley    AZ
# 1   DDS         24 N Bullmoose Cir              NaN         Chandler    AZ
# 2   DDS    2470 W Ray Road Suite 1              NaN         Chandler    AZ
# 3   DDS  6649 East Valle Di Cadore              NaN           Tucson    AZ
# 4   DDS               6938 E. Gary              NaN       Scottsdale    AZ
#
#   Zip.Code     License.Type License.Issue.Date   Dental.School  \
# 0    85253  Dentist License         1987-06-10  U of Pittsburg
# 1    85224  Dentist License         2009-06-11            SUNY
# 2    85224  Dentist License         2001-07-16      U of TX/SA
# 3    85750  Dentist License         1963-01-01              NW
# 4    85254  Dentist License         1979-12-13    U of Detroit
#
#   Graduation.Date broker.ID approach.date  convert
# 0      01/01/1970     chris    2017-08-04        1
# 1      06/01/2007     chris    2017-06-17        0
# 2      05/26/2001      karl    2017-07-03        0
# 3      01/01/1957     chris    2016-11-14        0
# 4      01/01/1965     sarah    2017-08-27        0

# %%
train_df['License.Type']
# Out:
# array(['Dentist License'], dtype=object)

# %%
# Out:
# Title                   52
# Address.1st.Line         0
# Address.2nd.Line      2877
# City                     0
# State                    0
# Zip.Code                 0
# License.Type             0
# License.Issue.Date       0
# Dental.School            1
# Graduation.Date          0
# broker.ID                0
# approach.date            0
# convert                  0
# dtype: int64

# %%
train_df['License.Issue.Date'] = pd.to_datetime(train_df.loc[:, 'License.Issue.Date'], )

# %%
date_today = dt.datetime.now()

# %%
train_df['time_since_license'] = train_df['License.Issue.Date'].apply(lambda x: date_today - x)

# %%
def get_days(timedelta_obj):
    obj = str(timedelta_obj)
    return int(obj.split(' ')[0])#get just the days

# %%
train_df.time_since_license = train_df.time_since_license.apply(lambda x: get_days(x))

# %%
train_df.head()
# Out:
#   Title           Address.1st.Line Address.2nd.Line             City State  \
# 0   DMD      6335 E. Mountain View              NaN  Paradise Valley    AZ
# 1   DDS         24 N Bullmoose Cir              NaN         Chandler    AZ
# 2   DDS    2470 W Ray Road Suite 1              NaN         Chandler    AZ
# 3   DDS  6649 East Valle Di Cadore              NaN           Tucson    AZ
# 4   DDS               6938 E. Gary              NaN       Scottsdale    AZ
#
#   Zip.Code     License.Type License.Issue.Date   Dental.School  \
# 0    85253  Dentist License         1987-06-10  U of Pittsburg
# 1    85224  Dentist License         2009-06-11            SUNY
# 2    85224  Dentist License         2001-07-16      U of TX/SA
# 3    85750  Dentist License         1963-01-01              NW
# 4    85254  Dentist License         1979-12-13    U of Detroit
#
#   Graduation.Date broker.ID approach.date  convert  time_since_license
# 0      01/01/1970     chris    2017-08-04        1               11553
# 1      06/01/2007     chris    2017-06-17        0                3516
# 2      05/26/2001      karl    2017-07-03        0                6403
# 3      01/01/1957     chris    2016-11-14        0               20479
# 4      01/01/1965     sarah    2017-08-27        0               14289
